# %%
# !pip install matplotlib-venn wordcloud
# Out:
# Requirement already satisfied: matplotlib-venn in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (1.1.2)
# Requirement already satisfied: wordcloud in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (1.9.4)
# Requirement already satisfied: matplotlib in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (3.10.0)
# Requirement already satisfied: numpy in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (2.2.5)
# Requirement already satisfied: scipy in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.15.3)
# Requirement already satisfied: pillow in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)

# %%
tips=sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('whitegrid')

fig=plt.subplots(figsize=(10,3))

tipgraph= sns.lineplot(data=tips,
             x='total_bill',y='tip',
             color='hotpink',
             linestyle='--',
             linewidth=3,
             marker='o',
             markerfacecolor='indigo')
tipgraph.set(title='Tips vs. Total Bill',
             xlabel='Total Bill($)',
             ylabel='Tip Amount($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill($)'),
#  Text(0, 0.5, 'Tip Amount($)')]

# %%
tipgraph = sns.scatterplot(data=tips,
                         x='total_bill',
                         y='tip',
                         style='time',
                         hue='day',
                         palette= ['purple','hotpink','deepsekblue','yellow'])

tipgraph.set(title='Tips Vs. Total Bill',
             xlabel='Total Bill',
             ylabel='Tip Amount')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tipgraph = sns.scatterplot(data=tips,
#       2                          x='total_bill',
#       3                          y='tip',
#       4                          style='time',
#       5                          hue='day',
#       6                          palette= ['purple','hotpink','deepsekblue','yellow'])
#       8 tipgraph.set(title='Tips Vs. Total Bill',
#       9              xlabel='Total Bill',
#      10              ylabel='Tip Amount')
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\seaborn\relational.py:443, in _ScatterPlotter.plot(self, ax, kws)
#     440 # Apply the mapping from semantic variables to artist attributes
#     442 if "hue" in self.variables:
# --> 443     points.set_facecolors(self._hue_map(data["hue"]))
#     445 if "size" in self.variables:
#     446     points.set_sizes(self._size_map(data["size"]))
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\_api\__init__.py:248, in define_aliases.<locals>.make_alias.<locals>.method(self, *args, **kwargs)
#     246 @functools.wraps(getattr(cls, name))
#     247 def method(self, *args, **kwargs):
# --> 248     return getattr(self, name)(*args, **kwargs)
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\collections.py:796, in Collection.set_facecolor(self, c)
#     794     c = c.lower()
#     795 self._original_facecolor = c
# --> 796 self._set_facecolor(c)
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\collections.py:778, in Collection._set_facecolor(self, c)
#     775 if c is None:
#     776     c = self._get_default_facecolor()
# --> 778 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     779 self.stale = True
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\colors.py:512, in to_rgba_array(c, alpha)
#     510         rgba = np.array(c)
#     511     else:
# --> 512         rgba = np.array([to_rgba(cc) for cc in c])
#     513 else:
#     514     rgba = np.array([to_rgba(cc) for cc in c])
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\colors.py:512, in <listcomp>(.0)
#     510         rgba = np.array(c)
#     511     else:
# --> 512         rgba = np.array([to_rgba(cc) for cc in c])
#     513 else:
#     514     rgba = np.array([to_rgba(cc) for cc in c])
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\colors.py:316, in to_rgba(c, alpha)
#     314     rgba = None
#     315 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 316     rgba = _to_rgba_no_colorcycle(c, alpha)
#     317     try:
#     318         _colors_full_map.cache[c, alpha] = rgba
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\colors.py:393, in _to_rgba_no_colorcycle(c, alpha)
#     389             raise ValueError(
#     390                 f"Invalid string grayscale value {orig_c!r}. "
#     391                 f"Value must be within 0-1 range")
#     392         return c, c, c, alpha if alpha is not None else 1.
# --> 393     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     394 # turn 2-D array into 1-D array
#     395 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'deepsekblue'
# Error in callback <function _draw_all_if_interactive at 0x00000166F7B065F0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# -> 1891         self.draw(*args, **kwargs)
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axes\_base.py:3181, in _AxesBase.draw(self, renderer)
#    3178 if artists_rasterized:
#    3179     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3181 mimage._draw_list_compositing_images(
#    3182     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3184 renderer.close_group('axes')
#    3185 self.stale = False
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\collections.py:1017, in _CollectionWithSizes.draw(self, renderer)
#    1014 @artist.allow_rasterization
#    1015 def draw(self, renderer):
#    1016     self.set_sizes(self._sizes, self.get_figure(root=True).dpi)
# -> 1017     super().draw(renderer)
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\collections.py:358, in Collection.draw(self, renderer)
#     355     return
#     356 renderer.open_group(self.__class__.__name__, self.get_gid())
# --> 358 self.update_scalarmappable()
#     360 transform, offset_trf, offsets, paths = self._prepare_points()
#     362 gc = renderer.new_gc()
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\collections.py:937, in Collection.update_scalarmappable(self)
#     935     self._facecolors = self._mapped_colors
#     936 else:
# --> 937     self._set_facecolor(self._original_facecolor)
#     938 if self._edge_is_mapped:
#     939     self._edgecolors = self._mapped_colors
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\collections.py:778, in Collection._set_facecolor(self, c)
#     775 if c is None:
#     776     c = self._get_default_facecolor()
# --> 778 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     779 self.stale = True
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\colors.py:512, in to_rgba_array(c, alpha)
#     510         rgba = np.array(c)
#     511     else:
# --> 512         rgba = np.array([to_rgba(cc) for cc in c])
#     513 else:
#     514     rgba = np.array([to_rgba(cc) for cc in c])
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\colors.py:512, in <listcomp>(.0)
#     510         rgba = np.array(c)
#     511     else:
# --> 512         rgba = np.array([to_rgba(cc) for cc in c])
#     513 else:
#     514     rgba = np.array([to_rgba(cc) for cc in c])
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\colors.py:316, in to_rgba(c, alpha)
#     314     rgba = None
#     315 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 316     rgba = _to_rgba_no_colorcycle(c, alpha)
#     317     try:
#     318         _colors_full_map.cache[c, alpha] = rgba
#
# File c:\Users\vidhi\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\colors.py:393, in _to_rgba_no_colorcycle(c, alpha)
#     389             raise ValueError(
#     390                 f"Invalid string grayscale value {orig_c!r}. "
#     391                 f"Value must be within 0-1 range")
#     392         return c, c, c, alpha if alpha is not None else 1.
# --> 393     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     394 # turn 2-D array into 1-D array
#     395 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'deepsekblue'

# %%
sns.pairplot(data=tips,
             hue='day')

# %%
daysplot=sns.relplot(data=tips,x="total_bill",
                    y="tip",hue="sex",
                    col="day",kind="scatter",
                    col_wrap=2)

# %%
np.random.seed(613)
x1=np.arange(50)
y1=np.random.randint(0,75,50)
x2=np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y2=np.array([110,180,240,99,220])

# %%
fig,(ax1,ax2)=plt.subplots(ncols=2,
                           nrows=1,
                           figsize=(7,3))
ax1.scatter(x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>
